# %% [markdown]
# <a href="https://colab.research.google.com/github/sonasejidli/Chatboot-1/blob/main/Chatboot_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
import random # Import the random module



nltk.download('punkt_tab') # Download the 'punkt_tab' data package

# Download necessary NLTK datasets
nltk.download('stopwords')
nltk.download('punkt')  # Ensure the punkt tokenizer is downloaded
nltk.download('wordnet')

from google.colab import files
uploaded = files.upload()  # Faylı seçib yükləmək üçün

with open("knowledge_base.txt", "r", encoding="utf-8") as f:
    documents = f.readlines()
documents = [doc.strip() for doc in documents if doc.strip()]

# Preprocessing Functions
def preprocess_text(text):
    # Tokenize the text
    tokens = word_tokenize(text)

   # İngilis dilində stopwords silmək əvəzinə:
    stop_words = set(stopwords.words('english'))

# Öz stopword siyahını təyin et (və ya tərcümə et)
    az_stopwords = {'və', 'amma', 'da', 'ki', 'mən', 'sən', 'biz', 'onlar', 'çox', 'az', 'həm'}

# Filtrləmə hissəsində dəyiş:
    filtered_words = [word for word in tokens if word.lower() not in az_stopwords]


    # Lemmatize the words
    lemmatizer = WordNetLemmatizer()
    lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]

    # Stem the words
    stemmer = PorterStemmer()
    stemmed_words = [stemmer.stem(word) for word in lemmatized_words]

    return ' '.join(stemmed_words)



# Nəticəni list şəklində saxla
motivation_patterns = list(generated_intents)



file_path

intents = [
    {"intent": "motivation", "patterns": [
    "Mən motivasiyaya ehtiyacım var",
    "Özümü motivasiyasız hiss edirəm",
    "Çox yorulmuşam, nəsə ruhlandırıcı de",
    "İrəli getmək çətindir", "Məni ruhlandır",
    "Həyat mənim üçün çətin olub", "Dəstəyə ehtiyacım var"
    "Yorğunam"]}]




# Preprocess all patterns for intent recognition
all_patterns = []
responses = []
intent_labels = []

for intent in intents:
    for pattern in intent["patterns"]:
        processed_text = preprocess_text(pattern)
        all_patterns.append(processed_text)

        intent_labels.append(intent["intent"])

# Convert patterns into TF-IDF features
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(all_patterns)

# Nearest Neighbors model for intent recognition
model = NearestNeighbors(n_neighbors=1, metric='cosine')
model.fit(X)

# Function to predict the intent of a user's message
def predict_intent(user_input):
    processed_input = preprocess_text(user_input)
    user_input_tfidf = vectorizer.transform([processed_input])
    _, indices = model.kneighbors(user_input_tfidf)
    intent_idx = indices[0][0]

    print(f"Processed Input: {processed_input}")  # Debugging line to see processed input
    print(f"Matched Intent: {intent_labels[intent_idx]}")  # Debugging line to see matched intent

    intent = intent_labels[intent_idx]

    return response
    # **Motivasiya Chatbotu üçün Məlumat Bazası**
    intent_data = {
    "salam": ["Salam! Necəsən?", "Salam, dostum! Sənə necə kömək edə bilərəm?", "Salam! Bugün özünü necə hiss edirsən?"],
    "vida": ["Sağ ol! Yenidən görüşənədək!", "Özünə yaxşı bax!", "Hələlik! Hər şeyin yaxşı olmasını arzulayıram!"],
    "motivasiya": [
        "Böyük nailiyyətlər kiçik addımlarla başlayır. Davam et!",
        "Bugün çətin ola bilər, amma sabah daha yaxşı olacaq.",
        "Öz gücünə inan! Hər uğur bir vaxtlar mümkünsüz görünürdü.",
        "Unutma, heç kim mükəmməl deyil. Əsas odur ki, irəliləyişə davam edəsən.",
        "Hər uğursuzluq bir dərsdir. Sən daha güclü olacaqsan!"
    ],
    "diqqət": [
        "Diqqətini cəmləmək üçün kiçik fasilələr et və bir məqsədə fokuslan.",
        "Telefonunu kənara qoy və 25 dəqiqəlik ‘Pomodoro’ texnikasını sına.",
        "Sakit bir yer tap və musiqi ilə diqqətini cəmlə."
    ],
    "narahatlıq": [
        "Narahat olmaq normaldır, ancaq hər şey keçicidir. Dərindən nəfəs al.",
        "Özünü rahat hiss etmək üçün meditasiya və ya kiçik bir gəzinti et.",
        "Səni narahat edən şeyləri kağıza yaz. Bu sənə sakitləşməyə kömək edəcək."
    ],
    "çətinlik": [
        "Hər problem həll edilə bilər, sadəcə, onu kiçik hissələrə böl.",
        "İlk addımı atmaq həmişə çətindir. Amma sən bacararsan!",
        "Bu gün çətinlik çəkirsənsə, unutma ki, bu, irəliləyişin bir hissəsidir."
    ],
    "pis_hiss": [
        "Hamımızın pis günləri olur, amma unutma ki, bu hisslər keçicidir.",
        "Özünü daha yaxşı hiss etmək üçün bir dostunla danış və ya təmiz havaya çıx.",
        "Özünü pis hiss edəndə, xatırla ki, sən dəyərlisən və tək deyilsən."
    ]}

# Chatbot Interaction
def chatbot():
    print("Chatbot: Hello! How can I assist you today?")

    while True:
        user_input = input("You: ")
        if user_input.lower() in ['exit', 'quit', 'bye']:
            print("Chatbot: Goodbye!")
            break

        response = predict_intent(user_input)
        print(f"Chatbot: {response}")

# Run the chatbot
chatbot()
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#      <input type="file" id="files-fed193c9-797c-4ffb-a558-494a29ce5df4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fed193c9-797c-4ffb-a558-494a29ce5df4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

# Download necessary NLTK datasets
nltk.download('stopwords')
nltk.download('punkt')  # Ensure the punkt tokenizer is downloaded
nltk.download('wordnet')

# Preprocessing Functions
def preprocess_text(text):
    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in tokens if word.lower() not in stop_words]

    # Lemmatize the words
    lemmatizer = WordNetLemmatizer()
    lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]

    # Stem the words
    stemmer = PorterStemmer()
    stemmed_words = [stemmer.stem(word) for word in lemmatized_words]

    return ' '.join(stemmed_words)

# Create a dataset of predefined intents and responses
intents = [
    {"intent": "greeting", "patterns": ["Hi", "Hello", "Hey", "How are you?", "Good morning", "Hello there"], "responses": ["Hello!", "Hi there!", "How can I assist you today?"]},
    {"intent": "goodbye", "patterns": ["Bye", "Goodbye", "See you later", "Take care", "See ya"], "responses": ["Goodbye!", "See you!", "Take care!"]},
    {"intent": "thanks", "patterns": ["Thanks", "Thank you", "Thanks a lot", "Appreciate it"], "responses": ["You're welcome!", "Happy to help!", "Anytime!"]},
    {"intent": "info", "patterns": ["What is your name?", "Who are you?", "Tell me about yourself", "What do you do?"], "responses": ["I am an NLP Bot.", "I am here to assist you!", "I am a chatbot created to chat with you."]},
    {"intent": "help", "patterns": ["Help me", "I need help", "Can you help me?", "Assist me", "I feel bad", "I'm distracted", "I'm feeling nervous", "I'm anxious", "I'm overwhelmed"],
     "responses": ["I'm here to help you. Let's take a deep breath and talk about what's on your mind.",
                   "It’s okay to feel nervous. Take a step back and breathe. You’ve got this!",
                   "I’m here for you, you’re not alone. How can I support you in this moment?",
                   "Feeling anxious is normal. Let’s break things down and take it one step at a time.",
                   "When you feel overwhelmed, try to focus on small tasks. Start slow and keep going."]
    },
    {"intent": "motivation", "patterns": ["Tell me motivational words", "Give me advice", "I need some motivation", "Help me stay focused", "I feel lost", "I feel nervous", "I'm struggling"],
     "responses": [
         "Remember, progress comes in small steps. Stay focused and take one task at a time.",
         "You are stronger than you think. Keep going, the best version of yourself is waiting!",
         "Even on tough days, you're making progress. Keep moving forward, one step at a time.",
         "The road may be tough, but every step forward is a victory. You’re closer than you think.",
         "Believe in your abilities. You’ve overcome challenges before, and you will again.",
         "Take things one moment at a time. You can handle this, just breathe.",
         "You don’t have to be perfect, just take action. You’re doing better than you think.",
         "Keep your head up. Every challenge is an opportunity for growth.",
         "Don't give up. Each day you get closer to the version of yourself you want to be.",
         "Challenges don’t define you. How you respond to them does.",
         "Focus on what you can control, and let go of what you can’t. You have the power to adapt.",
         "You’re not here by accident. You have everything you need to succeed.",
         "Believe in yourself—your hard work will pay off. You’re capable of amazing things.",
         "The greatest achievements come from pushing through discomfort. You’ve got this!",
         "No matter how small the progress, it’s still progress. Keep moving forward.",
         "It’s okay to pause and breathe. Sometimes, that’s exactly what you need to refocus.",
         "Don’t let the pressure overwhelm you. Break it into smaller tasks and conquer them one by one.",
         "When you feel unsure, take a moment to reconnect with your goals. You’ll find your way.",
         "The only limit is the one you set for yourself. Keep challenging those limits!",
         "Trust the process. Growth happens slowly, but it is happening.",
         "You’ve faced challenges before and overcome them. Trust yourself—you can do it again.",
         "You are not alone. Many people feel nervous, but your strength is in overcoming it.",
         "Take a deep breath and remind yourself that you are capable of handling whatever comes your way.",
         "In the face of doubt, trust in the actions you can take. Every small step counts.",
         "You’re learning and growing with every experience. Keep going—you’re doing great.",
         "Confidence comes from doing. Every step you take brings you closer to where you want to be.",
         "Sometimes, the hardest part is starting. Once you begin, everything else becomes easier.",
         "Don’t be afraid to take breaks when you need them. Rest is an important part of progress.",
         "Remember why you started. Your vision will guide you through difficult times.",
         "Be proud of how far you’ve come, not just how far you have to go.",
         "Success is not about never feeling nervous—it’s about doing it anyway.",
         "Growth happens when you step outside of your comfort zone. Embrace the discomfort and keep moving.",
         "You are worthy of everything you’re working toward. Don’t doubt your potential.",
         "When you feel overwhelmed, take a step back and remind yourself why you’re here. You’ve got this.",
         "You’ve made it through every tough moment in the past—this one is no different.",
         "Every challenge is a lesson in resilience. You’re growing stronger with every experience.",
         "You don’t have to know the entire path. Just take the next step, and you’ll get there.",
         "Believe in your growth. Even if you feel uncertain, keep going and you’ll see the results.",
         "Don’t rush—take it one day at a time. The journey is just as important as the destination.",
         "Trust that you are on the right path. Every step, no matter how small, matters.",
         "You are allowed to be nervous. What matters is that you don’t let it stop you.",
         "Take a deep breath and allow yourself to move at your own pace. You have the time to succeed.",
         "You are not defined by your nerves or fears. You are defined by your actions and choices.",
         "The most successful people have faced nerves and fears. It’s how you handle them that makes the difference.",
         "Success is built on persistence. Keep moving, even when things feel uncertain.",
         "The journey may be difficult, but the view from the top is worth it. Keep going!",
         "You are capable of more than you think. Believe in yourself and take that first step."
     ]}
]

# Preprocess all patterns for intent recognition
all_patterns = []
responses = []
intent_labels = []

for intent in intents:
    for pattern in intent["patterns"]:
        processed_text = preprocess_text(pattern)
        all_patterns.append(processed_text)
        responses.append(intent["responses"])
        intent_labels.append(intent["intent"])

# Convert patterns into TF-IDF features
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(all_patterns)

# Nearest Neighbors model for intent recognition
model = NearestNeighbors(n_neighbors=1, metric='cosine')
model.fit(X)

# Function to predict the intent of a user's message
def predict_intent(user_input):
    processed_input = preprocess_text(user_input)
    user_input_tfidf = vectorizer.transform([processed_input])
    _, indices = model.kneighbors(user_input_tfidf)
    intent_idx = indices[0][0]

    print(f"Processed Input: {processed_input}")  # Debugging line to see processed input
    print(f"Matched Intent: {intent_labels[intent_idx]}")  # Debugging line to see matched intent

    intent = intent_labels[intent_idx]
    response = responses[intent_idx][0]  # Respond with the first available response
    return response

# Chatbot Interaction
def chatbot():
    print("Chatbot: Hello! How can I assist you today?")

    while True:
        user_input = input("You: ")
        if user_input.lower() in ['exit', 'quit', 'bye']:
            print("Chatbot: Goodbye!")
            break

        response = predict_intent(user_input)
        print(f"Chatbot: {response}")

# Run the chatbot
chatbot()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-2-d3b5aa649468> in <cell line: 0>()
#     102 for intent in intents:
#     103     for pattern in intent["patterns"]:
# --> 104         processed_text = preprocess_text(pattern)
#     105         all_patterns.append(processed_text)
#     106         responses.append(intent["responses"])
#
# <ipython-input-2-d3b5aa649468> in preprocess_text(text)
#      14 def preprocess_text(text):
#      15     # Tokenize the text
# ---> 16     tokens = word_tokenize(text)
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

# Download necessary NLTK datasets
nltk.download('stopwords')
nltk.download('punkt')  # Ensure the punkt tokenizer is downloaded
nltk.download('wordnet')

# Preprocessing Functions
def preprocess_text(text):
    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in tokens if word.lower() not in stop_words]

    # Lemmatize the words
    lemmatizer = WordNetLemmatizer()
    lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]

    # Stem the words
    stemmer = PorterStemmer()
    stemmed_words = [stemmer.stem(word) for word in lemmatized_words]

    return ' '.join(stemmed_words)

# Create a dataset of predefined intents and responses
intents = [
    {"intent": "greeting", "patterns": ["Hi", "Hello", "Hey", "How are you?", "Good morning", "Hello there"], "responses": ["Hello!", "Hi there!", "How can I assist you today?"]},
    {"intent": "goodbye", "patterns": ["Bye", "Goodbye", "See you later", "Take care", "See ya"], "responses": ["Goodbye!", "See you!", "Take care!"]},
    {"intent": "thanks", "patterns": ["Thanks", "Thank you", "Thanks a lot", "Appreciate it"], "responses": ["You're welcome!", "Happy to help!", "Anytime!"]},
    {"intent": "info", "patterns": ["What is your name?", "Who are you?", "Tell me about yourself", "What do you do?"], "responses": ["I am an NLP Bot.", "I am here to assist you!", "I am a chatbot created to chat with you."]},
    {"intent": "help", "patterns": ["Help me", "I need help", "Can you help me?", "Assist me", "I feel bad", "I'm distracted", "I'm feeling nervous", "I'm anxious", "I'm overwhelmed"],
     "responses": ["I'm here to help you. Let's take a deep breath and talk about what's on your mind.",
                   "It’s okay to feel nervous. Take a step back and breathe. You’ve got this!",
                   "I’m here for you, you’re not alone. How can I support you in this moment?",
                   "Feeling anxious is normal. Let’s break things down and take it one step at a time.",
                   "When you feel overwhelmed, try to focus on small tasks. Start slow and keep going."]
    },
    {"intent": "unmotivated", "patterns": ["I feel unmotivated", "I'm not feeling motivated", "I have no motivation", "I don't feel like doing anything"],
     "responses": ["It’s okay to feel unmotivated sometimes. Try setting small, achievable goals to get back on track.",
                   "Motivation can be tough, but taking small steps towards your goal can help you gain momentum.",
                   "Remember, even small progress is still progress. Start small, and the motivation will follow."]
    },
    {"intent": "task_difficulty", "patterns": ["I can't do my tasks", "I'm struggling with my tasks", "My tasks feel too hard", "I can't finish my work"],
     "responses": ["Take one task at a time. Break things down into smaller steps and focus on completing one part at a time.",
                   "It’s normal to feel overwhelmed, but remember that each task is a small piece of the bigger picture. You can do it.",
                   "When tasks seem too hard, start with the easiest one. Once you make progress, things will get easier."]
    },
    {"intent": "focus", "patterns": ["Help me stay focused", "I can't focus", "I need help staying focused", "I'm easily distracted"],
     "responses": ["Focus can be hard, but you can try setting short timers and focusing on one task at a time.",
                   "Try minimizing distractions and give yourself breaks between tasks. It’ll help your focus in the long run.",
                   "Focus is built over time. Start with small tasks and gradually increase your focus as you go."]
    },
    {"intent": "motivation", "patterns": ["Tell me motivational words", "Give me advice", "I need some motivation", "Help me stay focused", "I feel lost", "I feel nervous", "I'm struggling"],
     "responses": [
         "Remember, progress comes in small steps. Stay focused and take one task at a time.",
         "You are stronger than you think. Keep going, the best version of yourself is waiting!",
         "Even on tough days, you're making progress. Keep moving forward, one step at a time.",
         "The road may be tough, but every step forward is a victory. You’re closer than you think.",
         "Believe in your abilities. You’ve overcome challenges before, and you will again.",
         "Take things one moment at a time. You can handle this, just breathe.",
         "You don’t have to be perfect, just take action. You’re doing better than you think.",
         "Keep your head up. Every challenge is an opportunity for growth.",
         "Don't give up. Each day you get closer to the version of yourself you want to be.",
         "Challenges don’t define you. How you respond to them does."
     ]}
]

# Preprocess all patterns for intent recognition
all_patterns = []
responses = []
intent_labels = []

for intent in intents:
    for pattern in intent["patterns"]:
        processed_text = preprocess_text(pattern)
        all_patterns.append(processed_text)
        responses.append(intent["responses"])
        intent_labels.append(intent["intent"])

# Convert patterns into TF-IDF features
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(all_patterns)

# Nearest Neighbors model for intent recognition
model = NearestNeighbors(n_neighbors=1, metric='cosine')
model.fit(X)

# Function to predict the intent of a user's message
def predict_intent(user_input):
    processed_input = preprocess_text(user_input)
    user_input_tfidf = vectorizer.transform([processed_input])
    _, indices = model.kneighbors(user_input_tfidf)
    intent_idx = indices[0][0]

    print(f"Processed Input: {processed_input}")  # Debugging line to see processed input
    print(f"Matched Intent: {intent_labels[intent_idx]}")  # Debugging line to see matched intent

    intent = intent_labels[intent_idx]
    response = responses[intent_idx][0]  # Respond with the first available response
    return response

# Chatbot Interaction
def chatbot():
    print("Chatbot: Hello! How can I assist you today?")

    while True:
        user_input = input("You: ")
        if user_input.lower() in ['exit', 'quit', 'bye']:
            print("Chatbot: Goodbye!")
            break

        response = predict_intent(user_input)
        print(f"Chatbot: {response}")

# Run the chatbot
chatbot()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Chatbot: Hello! How can I assist you today?
# You: I'm overwhelmed
# Processed Input: 'm overwhelm
# Matched Intent: help
# Chatbot: I'm here to help you. Let's take a deep breath and talk about what's on your mind.
# You: I don't feel like doing anything
# Processed Input: n't feel like anyth
# Matched Intent: unmotivated
# Chatbot: It’s okay to feel unmotivated sometimes. Try setting small, achievable goals to get back on track.
# You: I can't finish my work
# Processed Input: ca n't finish work
# Matched Intent: task_difficulty
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

nltk.download('punkt')

# **Motivasiya Chatbotu üçün Məlumat Bazası**
intent_data = {
    "salam": ["Salam! Necəsən?", "Salam, dostum! Sənə necə kömək edə bilərəm?", "Salam! Bugün özünü necə hiss edirsən?"],
    "vida": ["Sağ ol! Yenidən görüşənədək!", "Özünə yaxşı bax!", "Hələlik! Hər şeyin yaxşı olmasını arzulayıram!"],
    "motivasiya": [
        "Böyük nailiyyətlər kiçik addımlarla başlayır. Davam et!",
        "Bugün çətin ola bilər, amma sabah daha yaxşı olacaq.",
        "Öz gücünə inan! Hər uğur bir vaxtlar mümkünsüz görünürdü.",
        "Unutma, heç kim mükəmməl deyil. Əsas odur ki, irəliləyişə davam edəsən.",
        "Hər uğursuzluq bir dərsdir. Sən daha güclü olacaqsan!"
    ],
    "diqqət": [
        "Diqqətini cəmləmək üçün kiçik fasilələr et və bir məqsədə fokuslan.",
        "Telefonunu kənara qoy və 25 dəqiqəlik ‘Pomodoro’ texnikasını sına.",
        "Sakit bir yer tap və musiqi ilə diqqətini cəmlə."
    ],
    "narahatlıq": [
        "Narahat olmaq normaldır, ancaq hər şey keçicidir. Dərindən nəfəs al.",
        "Özünü rahat hiss etmək üçün meditasiya və ya kiçik bir gəzinti et.",
        "Səni narahat edən şeyləri kağıza yaz. Bu sənə sakitləşməyə kömək edəcək."
    ],
    "çətinlik": [
        "Hər problem həll edilə bilər, sadəcə, onu kiçik hissələrə böl.",
        "İlk addımı atmaq həmişə çətindir. Amma sən bacararsan!",
        "Bu gün çətinlik çəkirsənsə, unutma ki, bu, irəliləyişin bir hissəsidir."
    ],
    "pis_hiss": [
        "Hamımızın pis günləri olur, amma unutma ki, bu hisslər keçicidir.",
        "Özünü daha yaxşı hiss etmək üçün bir dostunla danış və ya təmiz havaya çıx.",
        "Özünü pis hiss edəndə, xatırla ki, sən dəyərlisən və tək deyilsən."
    ]
}

# **Sözlərin Tokenizə Edilməsi və Modelin Hazırlanması**
all_patterns = []
responses = []
intent_labels = []

for intent, examples in intent_data.items():
    for example in examples:
        all_patterns.append(example.lower())
        responses.append(example)
        intent_labels.append(intent)

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(all_patterns)

model = NearestNeighbors(n_neighbors=1, metric='cosine')
model.fit(X)

# **İstifadəçi Sualına Ən Uyğun Cavabı Tapırıq**
def predict_intent(user_input):
    user_input = user_input.lower()
    user_input_tfidf = vectorizer.transform([user_input])
    _, indices = model.kneighbors(user_input_tfidf)
    intent_idx = indices[0][0]
    return responses[intent_idx]

# **Chatbotun İşləməsi**
def chatbot():
    print("Chatbot: Salam! Sənə necə kömək edə bilərəm?")

    while True:
        user_input = input("Sən: ")
        if user_input.lower() in ['çix', 'bitir', 'sagol']:
            print("Chatbot: Sağ ol! Yenidən görüşənədək!")
            break

        response = predict_intent(user_input)
        print(f"Chatbot: {response}")

# **Chatbotu İşə Salırıq**
chatbot()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Chatbot: Salam! Sənə necə kömək edə bilərəm?
# Sən: motivasiyam yoxdur
# Chatbot: Salam! Necəsən?
# Sən: pis
# Chatbot: Hamımızın pis günləri olur, amma unutma ki, bu hisslər keçicidir.
# Sən: sağ ol
# Chatbot: Sağ ol! Yenidən görüşənədək!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-d78af0dedc4e> in <cell line: 0>()
#      78
#      79 # **Chatbotu İşə Salırıq**
# ---> 80 chatbot()
#
# <ipython-input-13-d78af0dedc4e> in chatbot()
#      69
#      70     while True:
# ---> 71         user_input = input("Sən: ")
#      72         if user_input.lower() in ['çix', 'bitir', 'sagol']:
#      73             print("Chatbot: Sağ ol! Yenidən görüşənədək!")
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...
